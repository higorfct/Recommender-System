# %% [markdown]
# #Projeto 3 - Product Recommender System

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd  # Data manipulation and analysis with DataFrames (table structure)

from mlxtend.preprocessing import TransactionEncoder  # Converts transaction lists to binary format (needed for algorithms like Apriori)

from mlxtend.frequent_patterns import apriori, association_rules
# apriori: Algorithm to find frequent itemsets
# association_rules: Generates association rules from frequent itemsets

from io import StringIO  # Allows treating strings as files, useful for simulating data reading from text

# %% [markdown]
# ### Parameters for generating  rules

# %%
# for generating frequent itemsets (apriori)
suporte_minimo = 0.01 # minimum support
# for creating rules (association_rules)
confianca_minima = 0.2 # minimum confidence
# filters after rules were generated
lift_minimo = 1.5 # minimum lift
tamanho_minimo = 1  # minimum size of the antecedent (LHS)

# %% [markdown]
# ### Loading data

# %%
# put in list format
with open("transactions.csv", 'r', encoding='utf-8') as f:
  transactions = [line.strip().split(',') for line in f]
transactions
# Out:
# [['"Pasta', 'Eggs', 'Butter', 'Cheese', 'Milk', 'Cookies"'],
#  ['"Banana', 'Coffee', 'Chicken', 'Bread', 'Cookies', 'Rice"'],
#  ['"Chicken', 'Sugar', 'Eggs', 'Butter', 'Bread', 'Milk"'],
#  ['"Pasta', 'Bread', 'Beer"'],
#  ['"Sugar', 'Banana"'],
#  ['"Eggs', 'Milk', 'Cheese', 'Butter"'],
#  ['"Banana', 'Chicken"'],
#  ['"Milk', 'Bread"'],
#  ['"Rice', 'Beans', 'Sugar', 'Butter', 'Banana"'],
#  ['"Chicken', 'Pasta', 'Eggs', 'Coffee"'],
#  ['"Sugar', 'Chicken', 'Beer', 'Butter', 'Cookies', 'Coffee"'],
#  ['"Beer', 'Butter"'],
#  ['"Rice', 'Chicken"'],
#  ['"Beer', 'Pasta', 'Chicken', 'Coffee"'],
#  ['"Cookies', 'Beer', 'Banana', 'Rice', 'Beans"'],
#  ['"Banana', 'Beans', 'Beer', 'Cookies', 'Bread"'],
#  ['"Chicken', 'Pasta"'],
#  ['"Beans', 'Beer', 'Pasta"'],
#  ['"Butter', 'Eggs', 'Rice"'],
#  ['"Cookies', 'Milk"'],
#  ['"Cookies', 'Milk"'],
#  ['"Banana', 'Milk', 'Butter"'],
#  ['"Milk', 'Sugar', 'Cookies', 'Rice', 'Coffee"'],
#  ['"Beer', 'Eggs', 'Sugar', 'Pasta', 'Chicken', 'Milk"'],
#  ['"Beer', 'Beans', 'Milk', 'Eggs', 'Cookies', 'Banana"'],
#  ['"Beans', 'Coffee"'],
#  ['"Rice', 'Sugar', 'Beer', 'Cookies', 'Milk', 'Bread"'],
#  ['"Beer', 'Pasta', 'Sugar', 'Milk"'],
#  ['"Beans', 'Banana', 'Milk"'],
#  ['"Beer', 'Pasta', 'Butter', 'Sugar"'],
#  ['"Butter', 'Bread', 'Cheese', 'Pasta', 'Beer', 'Beans"'],
#  ['"Milk', 'Cheese', 'Banana', 'Cookies"'],
#  ['"Banana', 'Beer', 'Bread', 'Rice"'],
#  ['"Banana', 'Chicken', 'Cookies', 'Coffee"'],
#  ['"Bread', 'Beer"'],
#  ['"Cookies', 'Rice', 'Banana', 'Butter"'],
#  ['"Beans', 'Cheese', 'Beer"'],
#  ['"Pasta', 'Bread', 'Butter"'],
#  ['"Eggs', 'Rice', 'Cookies', 'Butter', 'Beans"'],
#  ['"Cheese', 'Pasta', 'Beer', 'Chicken', 'Banana', 'Milk"'],
#  ['"Beer', 'Pasta', 'Banana"'],
#  ['"Butter', 'Sugar', 'Bread"'],
#  ['"Pasta', 'Beer', 'Banana', 'Butter', 'Eggs', 'Coffee"'],
#  ['"Cheese', 'Chicken"'],
#  ['"Cheese', 'Beer"'],
#  ['"Cheese', 'Banana', 'Beer"'],
#  ['"Bread', 'Chicken"'],
#  ['"Rice', 'Pasta"'],
#  ['"Bread', 'Beans', 'Eggs', 'Chicken', 'Rice', 'Butter"'],
#  ['"Banana', 'Beans', 'Coffee', 'Bread"'],
#  ['"Cookies', 'Butter', 'Beer', 'Coffee"'],
#  ['"Cookies', 'Sugar"'],
#  ['"Bread', 'Chicken', 'Milk', 'Cheese', 'Pasta', 'Coffee"'],
#  ['"Milk', 'Pasta', 'Beer"'],
#  ['"Banana', 'Milk', 'Butter"'],
#  ['"Butter', 'Rice"'],
#  ['"Pasta', 'Milk', 'Cookies"'],
#  ['"Cookies', 'Rice', 'Pasta', 'Coffee', 'Milk', 'Eggs"'],
#  ['"Butter', 'Bread', 'Rice', 'Pasta"'],
#  ['"Milk', 'Bread', 'Butter', 'Beans', 'Rice"'],
#  ['"Chicken', 'Beans', 'Eggs', 'Cookies', 'Sugar"'],
#  ['"Pasta', 'Banana', 'Eggs"'],
#  ['"Banana', 'Milk', 'Cheese', 'Chicken', 'Sugar', 'Butter"'],
#  ['"Milk', 'Cookies', 'Butter"'],
#  ['"Chicken', 'Beer', 'Banana"'],
#  ['"Rice', 'Sugar', 'Bread', 'Cookies', 'Butter"'],
#  ['"Bread', 'Chicken', 'Butter', 'Banana"'],
#  ['"Banana', 'Eggs', 'Milk', 'Cookies', 'Bread"'],
#  ['"Rice', 'Banana', 'Sugar', 'Milk', 'Cookies', 'Eggs"'],
#  ['"Coffee', 'Beans', 'Chicken"'],
#  ['"Banana', 'Rice"'],
#  ['"Cookies', 'Butter"'],
#  ['"Coffee', 'Beer"'],
#  ['"Chicken', 'Cookies', 'Cheese', 'Beer', 'Eggs"'],
#  ['"Chicken', 'Milk', 'Cheese"'],
#  ['"Milk', 'Cookies', 'Eggs', 'Pasta', 'Beans"'],
#  ['"Milk', 'Chicken', 'Beans', 'Pasta', 'Coffee"'],
#  ['"Coffee', 'Banana', 'Butter', 'Rice"'],
#  ['"Pasta', 'Banana', 'Cookies', 'Chicken', 'Bread"'],
#  ['"Banana', 'Sugar', 'Chicken"'],
#  ['"Butter', 'Cheese', 'Beer', 'Bread', 'Eggs', 'Sugar"'],
#  ['"Cookies', 'Coffee', 'Cheese', 'Rice"'],
#  ['"Butter', 'Milk', 'Chicken', 'Banana', 'Sugar"'],
#  ['"Beer', 'Cheese', 'Banana"'],
#  ['"Chicken', 'Bread', 'Cookies', 'Beans"'],
#  ['"Sugar', 'Rice', 'Eggs', 'Bread', 'Cheese', 'Milk"'],
#  ['"Eggs', 'Butter', 'Banana"'],
#  ['"Coffee', 'Pasta"'],
#  ['"Bread', 'Coffee"'],
#  ['"Cheese', 'Eggs', 'Cookies', 'Banana', 'Beer"'],
#  ['"Eggs', 'Sugar', 'Beans', 'Cookies', 'Cheese', 'Pasta"'],
#  ['"Banana', 'Pasta', 'Cheese', 'Eggs', 'Beer', 'Sugar"'],
#  ['"Chicken', 'Rice', 'Sugar"'],
#  ['"Eggs', 'Milk', 'Coffee', 'Cheese', 'Pasta', 'Beer"'],
#  ['"Beer', 'Banana', 'Sugar"'],
#  ['"Sugar', 'Banana', 'Bread', 'Cookies"'],
#  ['"Pasta', 'Chicken', 'Butter"'],
#  ['"Coffee', 'Butter', 'Pasta', 'Milk', 'Chicken', 'Bread"'],
#  ['"Cheese', 'Banana', 'Milk"'],
#  ['"Beans', 'Banana', 'Rice', 'Beer', 'Sugar', 'Eggs"'],
#  ['"Eggs', 'Chicken', 'Beer', 'Coffee', 'Sugar', 'Cookies"'],
#  ['"Rice', 'Beer', 'Beans', 'Bread', 'Sugar"'],
#  ['"Coffee', 'Rice', 'Cookies', 'Beer', 'Sugar', 'Milk"'],
#  ['"Chicken', 'Cheese', 'Butter', 'Beer', 'Rice"'],
#  ['"Rice', 'Eggs', 'Butter"'],
#  ['"Cheese', 'Chicken', 'Coffee"'],
#  ['"Beer', 'Pasta', 'Sugar', 'Coffee', 'Milk', 'Beans"'],
#  ['"Pasta', 'Sugar', 'Beans', 'Bread', 'Butter"'],
#  ['"Bread', 'Sugar"'],
#  ['"Bread', 'Rice', 'Cookies"'],
#  ['"Pasta', 'Cheese', 'Rice', 'Milk', 'Cookies', 'Beer"'],
#  ['"Rice', 'Cheese', 'Pasta', 'Banana', 'Beans"'],
#  ['"Cheese', 'Rice"'],
#  ['"Cheese', 'Milk', 'Butter', 'Pasta', 'Rice"'],
#  ['"Banana', 'Eggs', 'Milk"'],
#  ['"Chicken', 'Cheese', 'Banana', 'Cookies', 'Beer', 'Sugar"'],
#  ['"Beans', 'Butter', 'Beer', 'Sugar"'],
#  ['"Bread', 'Butter"'],
#  ['"Banana', 'Milk', 'Chicken"'],
#  ['"Pasta', 'Sugar', 'Bread', 'Chicken', 'Beans"'],
#  ['"Beer', 'Sugar', 'Rice', 'Beans"'],
#  ['"Bread', 'Pasta', 'Butter"'],
#  ['"Beans', 'Pasta', 'Chicken', 'Milk"'],
#  ['"Cookies', 'Chicken', 'Beans', 'Bread', 'Coffee', 'Butter"'],
#  ['"Banana', 'Bread', 'Cookies', 'Eggs"'],
#  ['"Eggs', 'Beans', 'Coffee', 'Pasta', 'Bread"'],
#  ['"Cheese', 'Cookies"'],
#  ['"Pasta', 'Sugar', 'Banana', 'Rice', 'Cookies"'],
#  ['"Beer', 'Bread"'],
#  ['"Coffee', 'Rice', 'Beer', 'Cheese"'],
#  ['"Milk', 'Pasta', 'Cheese', 'Eggs', 'Cookies"'],
#  ['"Chicken', 'Beer', 'Eggs', 'Sugar"'],
#  ['"Cheese', 'Milk', 'Banana', 'Rice', 'Coffee"'],
#  ['"Butter', 'Chicken', 'Cheese', 'Sugar', 'Bread"'],
#  ['"Milk', 'Coffee', 'Eggs"'],
#  ['"Beer', 'Coffee', 'Beans', 'Banana', 'Chicken"'],
#  ['"Cookies', 'Cheese', 'Butter', 'Bread', 'Milk"'],
#  ['"Sugar', 'Bread"'],
#  ['"Sugar', 'Coffee"'],
#  ['"Beer', 'Bread', 'Coffee', 'Butter', 'Sugar', 'Rice"'],
#  ['"Butter', 'Coffee', 'Cheese', 'Beer"'],
#  ['"Milk', 'Banana"'],
#  ['"Rice', 'Milk', 'Chicken', 'Beer', 'Butter', 'Eggs"'],
#  ['"Pasta', 'Sugar', 'Rice', 'Coffee"'],
#  ['"Chicken', 'Beer', 'Pasta', 'Butter"'],
#  ['"Bread', 'Rice"'],
#  ['"Pasta', 'Cheese', 'Eggs', 'Bread', 'Sugar', 'Cookies"'],
#  ['"Beans', 'Butter', 'Milk', 'Rice', 'Banana"'],
#  ['"Bread', 'Butter"'],
#  ['"Cookies', 'Sugar"'],
#  ['"Banana', 'Cheese', 'Beer"'],
#  ['"Rice', 'Milk', 'Chicken', 'Sugar', 'Coffee"'],
#  ['"Rice', 'Cheese', 'Butter', 'Banana', 'Coffee', 'Beer"'],
#  ['"Cookies', 'Chicken', 'Beans', 'Sugar"'],
#  ['"Cookies', 'Beans', 'Milk', 'Banana', 'Sugar', 'Bread"'],
#  ['"Bread', 'Cheese', 'Butter', 'Coffee', 'Beans"'],
#  ['"Chicken', 'Eggs', 'Beans', 'Coffee', 'Milk"'],
#  ['"Bread', 'Coffee', 'Pasta', 'Milk"'],
#  ['"Butter', 'Rice', 'Cookies"'],
#  ['"Cookies', 'Chicken', 'Rice', 'Coffee"'],
#  ['"Bread', 'Butter', 'Rice', 'Pasta', 'Coffee"'],
#  ['"Rice', 'Eggs', 'Milk', 'Pasta', 'Sugar', 'Coffee"'],
#  ['"Chicken', 'Milk', 'Sugar', 'Rice"'],
#  ['"Sugar', 'Chicken', 'Bread', 'Cheese"'],
#  ['"Chicken', 'Eggs', 'Sugar', 'Coffee', 'Milk', 'Beans"'],
#  ['"Cheese', 'Rice"'],
#  ['"Coffee', 'Cheese', 'Bread', 'Cookies"'],
#  ['"Cheese', 'Bread"'],
#  ['"Pasta', 'Eggs', 'Bread', 'Butter"'],
#  ['"Cheese', 'Beans', 'Coffee', 'Pasta', 'Rice', 'Butter"'],
#  ['"Pasta', 'Banana', 'Beer', 'Coffee"'],
#  ['"Pasta', 'Cookies"'],
#  ['"Bread', 'Cheese"'],
#  ['"Beans', 'Sugar', 'Rice', 'Cheese', 'Cookies"'],
#  ['"Pasta', 'Chicken', 'Cookies', 'Cheese', 'Milk', 'Coffee"'],
#  ['"Sugar', 'Milk', 'Bread', 'Rice', 'Pasta"'],
#  ['"Butter', 'Cookies"'],
#  ['"Cookies', 'Butter', 'Bread', 'Chicken"'],
#  ['"Milk', 'Rice', 'Sugar', 'Banana', 'Cheese"'],
#  ['"Beans', 'Banana"'],
#  ['"Cookies', 'Rice', 'Sugar"'],
#  ['"Cookies', 'Eggs', 'Coffee', 'Rice', 'Butter"'],
#  ['"Milk', 'Pasta"'],
#  ['"Banana', 'Rice', 'Beer', 'Bread', 'Milk', 'Eggs"'],
#  ['"Sugar', 'Butter', 'Bread"'],
#  ['"Chicken', 'Cheese', 'Beer', 'Milk', 'Pasta', 'Coffee"'],
#  ['"Pasta', 'Milk', 'Rice', 'Bread', 'Coffee"'],
#  ['"Chicken', 'Milk', 'Rice"'],
#  ['"Butter', 'Rice', 'Sugar', 'Coffee', 'Beans', 'Pasta"'],
#  ['"Cookies', 'Beans', 'Coffee', 'Butter', 'Sugar', 'Chicken"'],
#  ['"Bread', 'Beer', 'Eggs', 'Beans', 'Coffee"'],
#  ['"Cookies', 'Chicken', 'Butter"'],
#  ['"Bread', 'Pasta', 'Rice', 'Cookies"'],
#  ['"Coffee', 'Beans', 'Beer', 'Chicken', 'Eggs"'],
#  ['"Beans', 'Coffee"'],
#  ['"Bread', 'Eggs', 'Chicken', 'Milk', 'Cookies', 'Pasta"'],
#  ['"Coffee', 'Pasta', 'Beer', 'Rice', 'Chicken', 'Bread"'],
#  ['"Sugar', 'Pasta"'],
#  ['"Beer', 'Coffee', 'Beans', 'Sugar', 'Cheese', 'Butter"'],
#  ['"Eggs', 'Beer', 'Cheese', 'Sugar', 'Coffee"'],
#  ['"Pasta', 'Milk', 'Eggs"'],
#  ['"Sugar', 'Chicken', 'Beans', 'Milk', 'Coffee', 'Cheese"'],
#  ['"Bread', 'Sugar', 'Milk', 'Rice', 'Chicken"'],
#  ['"Bread', 'Coffee"'],
#  ['"Bread', 'Sugar', 'Banana', 'Rice', 'Pasta"'],
#  ['"Milk', 'Beans', 'Banana', 'Eggs', 'Bread"'],
#  ['"Cookies', 'Milk', 'Chicken"'],
#  ['"Bread', 'Pasta', 'Chicken', 'Sugar', 'Coffee', 'Beer"'],
#  ['"Cookies', 'Banana', 'Chicken"'],
#  ['"Milk', 'Beer', 'Cheese', 'Pasta"'],
#  ['"Butter', 'Coffee', 'Chicken', 'Pasta', 'Cookies"'],
#  ['"Beer', 'Banana', 'Beans', 'Chicken"'],
#  ['"Cookies', 'Sugar', 'Coffee', 'Banana"'],
#  ['"Coffee', 'Chicken', 'Cookies', 'Bread', 'Cheese', 'Banana"'],
#  ['"Coffee', 'Chicken"'],
#  ['"Coffee', 'Milk"'],
#  ['"Cookies', 'Sugar"'],
#  ['"Cheese', 'Milk', 'Cookies', 'Rice', 'Eggs', 'Beer"'],
#  ['"Bread', 'Sugar"'],
#  ['"Coffee', 'Chicken', 'Banana', 'Pasta', 'Bread"'],
#  ['"Cookies', 'Chicken', 'Beans"'],
#  ['"Eggs', 'Banana', 'Sugar', 'Cookies', 'Bread', 'Beans"'],
#  ['"Coffee', 'Rice', 'Milk', 'Sugar', 'Chicken"'],
#  ['"Rice', 'Beans', 'Chicken', 'Coffee"'],
#  ['"Cookies', 'Cheese', 'Eggs"'],
#  ['"Chicken', 'Beans', 'Sugar', 'Butter', 'Banana"'],
#  ['"Beans', 'Chicken', 'Banana', 'Beer', 'Coffee"'],
#  ['"Milk', 'Bread', 'Sugar"'],
#  ['"Chicken', 'Pasta', 'Banana', 'Cookies"'],
#  ['"Beer', 'Cookies"'],
#  ['"Beer', 'Cookies', 'Coffee', 'Bread', 'Eggs"'],
#  ['"Sugar', 'Coffee', 'Beans', 'Milk', 'Eggs"'],
#  ['"Eggs', 'Sugar"'],
#  ['"Cookies', 'Banana', 'Beans', 'Sugar', 'Beer', 'Butter"'],
#  ['"Beans', 'Bread', 'Beer', 'Sugar', 'Cheese"'],
#  ['"Chicken', 'Pasta', 'Eggs', 'Coffee', 'Beer', 'Bread"'],
#  ['"Butter', 'Cookies', 'Sugar"'],
#  ['"Beans', 'Coffee"'],
#  ['"Eggs', 'Rice', 'Sugar', 'Milk"'],
#  ['"Chicken', 'Rice', 'Banana', 'Butter"'],
#  ['"Beans', 'Butter', 'Eggs', 'Milk', 'Chicken', 'Cookies"'],
#  ['"Cookies', 'Banana', 'Chicken', 'Rice"'],
#  ['"Banana', 'Milk"'],
#  ['"Cookies', 'Eggs"'],
#  ['"Milk', 'Cheese', 'Chicken', 'Banana"'],
#  ['"Cheese', 'Beans"'],
#  ['"Banana', 'Beer', 'Milk', 'Chicken', 'Bread"'],
#  ['"Banana', 'Milk', 'Cookies', 'Beans', 'Eggs', 'Rice"'],
#  ['"Eggs', 'Bread', 'Banana"'],
#  ['"Banana', 'Eggs', 'Butter', 'Beans', 'Rice"'],
#  ['"Pasta', 'Butter"'],
#  ['"Chicken', 'Beans', 'Beer', 'Cheese"'],
#  ['"Milk', 'Cookies', 'Beans', 'Bread', 'Butter', 'Pasta"'],
#  ['"Cheese', 'Beans', 'Cookies', 'Rice', 'Banana"'],
#  ['"Chicken', 'Milk', 'Bread', 'Pasta', 'Cheese"'],
#  ['"Eggs', 'Rice', 'Banana', 'Cookies"'],
#  ['"Chicken', 'Pasta', 'Sugar', 'Butter"'],
#  ['"Milk', 'Sugar', 'Eggs"'],
#  ['"Pasta', 'Coffee"'],
#  ['"Rice', 'Bread', 'Beans', 'Sugar"'],
#  ['"Pasta', 'Chicken', 'Cookies', 'Rice', 'Milk"'],
#  ['"Banana', 'Beer"'],
#  ['"Eggs', 'Rice', 'Coffee', 'Banana', 'Beans"'],
#  ['"Chicken', 'Coffee', 'Eggs', 'Rice', 'Sugar', 'Pasta"'],
#  ['"Butter', 'Bread', 'Banana', 'Rice', 'Milk', 'Coffee"'],
#  ['"Butter', 'Beer', 'Cheese', 'Eggs', 'Rice"'],
#  ['"Beans', 'Chicken"'],
#  ['"Butter', 'Sugar', 'Coffee"'],
#  ['"Cheese', 'Chicken"'],
#  ['"Coffee', 'Banana', 'Sugar"'],
#  ['"Banana', 'Beer', 'Rice"'],
#  ['"Coffee', 'Sugar"'],
#  ['"Butter', 'Chicken', 'Bread', 'Cheese', 'Sugar', 'Rice"'],
#  ['"Rice', 'Milk', 'Beer', 'Sugar', 'Beans"'],
#  ['"Milk', 'Eggs', 'Coffee"'],
#  ['"Cheese', 'Banana', 'Milk"'],
#  ['"Pasta', 'Chicken"'],
#  ['"Beans', 'Banana', 'Butter', 'Cookies', 'Coffee"'],
#  ['"Banana', 'Eggs', 'Pasta', 'Bread"'],
#  ['"Coffee', 'Butter', 'Eggs"'],
#  ['"Beer', 'Bread', 'Eggs', 'Pasta', 'Sugar', 'Coffee"'],
#  ['"Cheese', 'Banana', 'Beer"'],
#  ['"Beans', 'Rice"'],
#  ['"Beans', 'Bread', 'Beer"'],
#  ['"Milk', 'Banana', 'Eggs', 'Bread"'],
#  ['"Butter', 'Coffee', 'Milk', 'Rice"'],
#  ['"Rice', 'Chicken', 'Eggs', 'Banana', 'Coffee', 'Cheese"'],
#  ['"Coffee', 'Cheese', 'Milk"'],
#  ['"Cookies', 'Eggs', 'Coffee"'],
#  ['"Chicken', 'Cheese', 'Cooki']]

# %%
# Remove spaces and quotes from items
transactions = [[item.strip().replace('"', '') for item in trans] for trans in transactions]

# %% [markdown]
# ### Turning the dataset into transactions format

# %%
# products in columns
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
display(df.head())
# Out:
#    Banana  Beans   Beer  Bread  Butter  Cheese  Chicken  Coffee  Cooki  \
# 0   False  False  False  False    True    True    False   False  False
# 1    True  False  False   True   False   False     True    True  False
# 2   False  False  False   True    True   False     True   False  False
# 3   False  False   True   True   False   False    False   False  False
# 4    True  False  False  False   False   False    False   False  False
#
#    Cookies   Eggs   Milk  Pasta   Rice  Sugar
# 0     True   True   True   True  False  False
# 1     True  False  False  False   True  False
# 2    False   True   True  False  False   True
# 3    False  False  False   True  False  False
# 4    False  False  False  False  False   True

# %% [markdown]
# ### Mining frequent items

# %%
frequent_itemsets = apriori(df, min_support=suporte_minimo, use_colnames=True)
display(frequent_itemsets)
# Out:
#       support                                itemsets
# 0    0.303448                                (Banana)
# 1    0.248276                                 (Beans)
# 2    0.272414                                  (Beer)
# 3    0.300000                                 (Bread)
# 4    0.272414                                (Butter)
# ..        ...                                     ...
# 564  0.010345            (Milk, Rice, Pasta, Cookies)
# 565  0.013793            (Milk, Sugar, Rice, Cookies)
# 566  0.013793               (Milk, Rice, Eggs, Sugar)
# 567  0.010345   (Bread, Chicken, Pasta, Coffee, Beer)
# 568  0.010345  (Chicken, Pasta, Cheese, Milk, Coffee)
#
# [569 rows x 2 columns]

# %% [markdown]
# ### Mining rules

# %%
regras = association_rules(frequent_itemsets, metric='confidence', min_threshold=confianca_minima)
display(regras)
# Out:
#                   antecedents        consequents  antecedent support  \
# 0                    (Banana)            (Beans)            0.303448
# 1                     (Beans)           (Banana)            0.248276
# 2                    (Banana)             (Beer)            0.303448
# 3                      (Beer)           (Banana)            0.272414
# 4                    (Banana)            (Bread)            0.303448
# ...                       ...                ...                 ...
# 1491  (Milk, Coffee, Chicken)    (Pasta, Cheese)            0.034483
# 1492    (Milk, Pasta, Cheese)  (Coffee, Chicken)            0.037931
# 1493  (Pasta, Coffee, Cheese)    (Milk, Chicken)            0.017241
# 1494    (Milk, Pasta, Coffee)  (Cheese, Chicken)            0.037931
# 1495   (Milk, Coffee, Cheese)   (Pasta, Chicken)            0.024138
#
#       consequent support   support  confidence      lift  representativity  \
# 0               0.248276  0.079310    0.261364  1.052715               1.0
# 1               0.303448  0.079310    0.319444  1.052715               1.0
# 2               0.272414  0.093103    0.306818  1.126295               1.0
# 3               0.303448  0.093103    0.341772  1.126295               1.0
# 4               0.300000  0.072414    0.238636  0.795455               1.0
# ...                  ...       ...         ...       ...               ...
# 1491            0.058621  0.010345    0.300000  5.117647               1.0
# 1492            0.117241  0.010345    0.272727  2.326203               1.0
# 1493            0.100000  0.010345    0.600000  6.000000               1.0
# 1494            0.075862  0.010345    0.272727  3.595041               1.0
# 1495            0.093103  0.010345    0.428571  4.603175               1.0
#
#       leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0     0.003971    1.017719       0.071890  0.167883   0.017410    0.290404
# 1     0.003971    1.023505       0.066613  0.167883   0.022965    0.290404
# 2     0.010440    1.049633       0.160983  0.192857   0.047286    0.324295
# 3     0.010440    1.058223       0.154116  0.192857   0.055019    0.324295
# 4    -0.018621    0.919403      -0.269628  0.136364  -0.087662    0.240008
# ...        ...         ...            ...       ...        ...         ...
# 1491  0.008323    1.344828       0.833333  0.125000   0.256410    0.238235
# 1492  0.005898    1.213793       0.592593  0.071429   0.176136    0.180481
# 1493  0.008621    2.250000       0.847953  0.096774   0.555556    0.351724
# 1494  0.007467    1.270690       0.750299  0.100000   0.213026    0.204545
# 1495  0.008098    1.587069       0.802120  0.096774   0.369908    0.269841
#
# [1496 rows x 14 columns]

# %% [markdown]
# ### Rules filtering

# %%
regras_filtradas = regras[(regras['lift'] >= lift_minimo) &
                          (regras['antecedents'].apply(lambda x: len(x) >= tamanho_minimo))]
display(regras_filtradas[['antecedents','consequents','support', 'confidence', 'lift']])
# Out:
#                   antecedents        consequents   support  confidence  \
# 196          (Banana, Cheese)             (Beer)  0.031034    0.450000
# 225           (Banana, Bread)             (Eggs)  0.027586    0.380952
# 396          (Beans, Chicken)           (Coffee)  0.037931    0.478261
# 422          (Cookies, Beans)             (Eggs)  0.027586    0.380952
# 433             (Milk, Beans)             (Eggs)  0.027586    0.444444
# ...                       ...                ...       ...         ...
# 1491  (Milk, Coffee, Chicken)    (Pasta, Cheese)  0.010345    0.300000
# 1492    (Milk, Pasta, Cheese)  (Coffee, Chicken)  0.010345    0.272727
# 1493  (Pasta, Coffee, Cheese)    (Milk, Chicken)  0.010345    0.600000
# 1494    (Milk, Pasta, Coffee)  (Cheese, Chicken)  0.010345    0.272727
# 1495   (Milk, Coffee, Cheese)   (Pasta, Chicken)  0.010345    0.428571
#
#           lift
# 196   1.651899
# 225   1.534392
# 396   1.541063
# 422   1.534392
# 433   1.790123
# ...        ...
# 1491  5.117647
# 1492  2.326203
# 1493  6.000000
# 1494  3.595041
# 1495  4.603175
#
# [360 rows x 5 columns]

# %% [markdown]
# ### Statistics

# %%
print(f"Total Rules Generated: {len(regras)}")
print(f"Total Filtered Rules: {len(regras_filtradas)}")
print(f"Average Support: {regras_filtradas['support'].mean():.4f}")
print(f"Average Confidence: {regras_filtradas['confidence'].mean():.4f}")
print(f"Average Lift: {regras_filtradas['lift'].mean():.4f}")
# Out:
# Total Rules Generated: 1496
# Total Filtered Rules: 360
# Average Support: 0.0139
# Average Confidence: 0.5036
# Average Lift: 2.1564

# %% [markdown]
# ### Financial Impact of the Recommender System (simulation)
#
# To estimate the financial impact, we need to make a few assumptions about:
#
# 1.  **Average profit per transaction:** The profit you earn on average from each sale.
# 2. **Increase in conversion rate due to recommendations:** How much the likelihood of a customer making a purchase increases when they receive a relevant recommendation.
# 3. **Number of transactions:** The total number of transactions during the analysis period.
#
# With these assumptions, we can calculate the estimated financial impact.

# %%
# --- Assumptions ---
# Define the estimated average profit per transaction (in local currency)
lucro_medio_por_transacao = 5.00 # Example: R$ 5.00

# Define the estimated percentage increase in conversion rate due to recommendations
# For example, if recommendations increase the chance of purchase by 10%, use 0.10
aumento_conversao_percentual = 0.10 # Example: 10% increase

# Get the total number of transactions from the data
num_transacoes = 500 # Updated based on user input

# --- Financial Impact Calculation ---

# Estimate the number of additional transactions generated by recommendations
transacoes_adicionais_estimadas = num_transacoes * aumento_conversao_percentual

# Calculate the estimated financial impact
impacto_financeiro_estimado = transacoes_adicionais_estimadas * lucro_medio_por_transacao

# --- Displaying the Result ---
print(f"Total number of transactions: {num_transacoes}")
print(f"Estimated number of additional transactions from recommendations: {transacoes_adicionais_estimadas:.2f}")
print(f"Estimated financial impact of recommendations: R$ {impacto_financeiro_estimado:.2f}")
# Out:
# Total number of transactions: 500
# Estimated number of additional transactions from recommendations: 50.00
# Estimated financial impact of recommendations: R$ 250.00
