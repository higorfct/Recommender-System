# %% [markdown]
# #Projeto 3 - Sistema de Recomendação de Produtos

# %% [markdown]
# ### Importações

# %%
import pandas as pd  # Manipulação e análise de dados com DataFrames (estrutura de tabela)

from mlxtend.preprocessing import TransactionEncoder  # Converte listas de transações em formato binário (necessário para algoritmos como Apriori)

from mlxtend.frequent_patterns import apriori, association_rules
# apriori: Algoritmo para encontrar conjuntos frequentes de itens (itemsets)
# association_rules: Gera regras de associação a partir dos conjuntos frequentes

from io import StringIO  # Permite tratar strings como arquivos, útil para simular leitura de dados em texto

# %% [markdown]
# ### Parâmetros para Geração de Regras

# %%
# na geração dos conjuntos frequêntes (apriori)
suporte_minimo = 0.01
# na criação das regras (association_rules)
confianca_minima = 0.2
# filtros depois que regras foram geradas
lift_minimo = 1.5
tamanho_minimo = 1  # itens no antecedente (LHS)

# %% [markdown]
# ### Importa Dados

# %%
# coloca em formato de lista
with open("transacoes.csv", 'r', encoding='utf-8') as f:
  transactions = [line.strip().split(',') for line in f]
transactions
# Out:
# [['"Macarrão', 'Ovos', 'Manteiga', 'Queijo', 'Leite', 'Biscoitos"'],
#  ['"Banana', 'Café', 'Frango', 'Pão', 'Biscoitos', 'Arroz"'],
#  ['"Frango', 'Açúcar', 'Ovos', 'Manteiga', 'Pão', 'Leite"'],
#  ['"Macarrão', 'Pão', 'Cerveja"'],
#  ['"Açúcar', 'Banana"'],
#  ['"Ovos', 'Leite', 'Queijo', 'Manteiga"'],
#  ['"Banana', 'Frango"'],
#  ['"Leite', 'Pão"'],
#  ['"Arroz', 'Feijão', 'Açúcar', 'Manteiga', 'Banana"'],
#  ['"Frango', 'Macarrão', 'Ovos', 'Café"'],
#  ['"Açúcar', 'Frango', 'Cerveja', 'Manteiga', 'Biscoitos', 'Café"'],
#  ['"Cerveja', 'Manteiga"'],
#  ['"Arroz', 'Frango"'],
#  ['"Cerveja', 'Macarrão', 'Frango', 'Café"'],
#  ['"Biscoitos', 'Cerveja', 'Banana', 'Arroz', 'Feijão"'],
#  ['"Banana', 'Feijão', 'Cerveja', 'Biscoitos', 'Pão"'],
#  ['"Frango', 'Macarrão"'],
#  ['"Feijão', 'Cerveja', 'Macarrão"'],
#  ['"Manteiga', 'Ovos', 'Arroz"'],
#  ['"Biscoitos', 'Leite"'],
#  ['"Biscoitos', 'Leite"'],
#  ['"Banana', 'Leite', 'Manteiga"'],
#  ['"Leite', 'Açúcar', 'Biscoitos', 'Arroz', 'Café"'],
#  ['"Cerveja', 'Ovos', 'Açúcar', 'Macarrão', 'Frango', 'Leite"'],
#  ['"Cerveja', 'Feijão', 'Leite', 'Ovos', 'Biscoitos', 'Banana"'],
#  ['"Feijão', 'Café"'],
#  ['"Arroz', 'Açúcar', 'Cerveja', 'Biscoitos', 'Leite', 'Pão"'],
#  ['"Cerveja', 'Macarrão', 'Açúcar', 'Leite"'],
#  ['"Feijão', 'Banana', 'Leite"'],
#  ['"Cerveja', 'Macarrão', 'Manteiga', 'Açúcar"'],
#  ['"Manteiga', 'Pão', 'Queijo', 'Macarrão', 'Cerveja', 'Feijão"'],
#  ['"Leite', 'Queijo', 'Banana', 'Biscoitos"'],
#  ['"Banana', 'Cerveja', 'Pão', 'Arroz"'],
#  ['"Banana', 'Frango', 'Biscoitos', 'Café"'],
#  ['"Pão', 'Cerveja"'],
#  ['"Biscoitos', 'Arroz', 'Banana', 'Manteiga"'],
#  ['"Feijão', 'Queijo', 'Cerveja"'],
#  ['"Macarrão', 'Pão', 'Manteiga"'],
#  ['"Ovos', 'Arroz', 'Biscoitos', 'Manteiga', 'Feijão"'],
#  ['"Queijo', 'Macarrão', 'Cerveja', 'Frango', 'Banana', 'Leite"'],
#  ['"Cerveja', 'Macarrão', 'Banana"'],
#  ['"Manteiga', 'Açúcar', 'Pão"'],
#  ['"Macarrão', 'Cerveja', 'Banana', 'Manteiga', 'Ovos', 'Café"'],
#  ['"Queijo', 'Frango"'],
#  ['"Queijo', 'Cerveja"'],
#  ['"Queijo', 'Banana', 'Cerveja"'],
#  ['"Pão', 'Frango"'],
#  ['"Arroz', 'Macarrão"'],
#  ['"Pão', 'Feijão', 'Ovos', 'Frango', 'Arroz', 'Manteiga"'],
#  ['"Banana', 'Feijão', 'Café', 'Pão"'],
#  ['"Biscoitos', 'Manteiga', 'Cerveja', 'Café"'],
#  ['"Biscoitos', 'Açúcar"'],
#  ['"Pão', 'Frango', 'Leite', 'Queijo', 'Macarrão', 'Café"'],
#  ['"Leite', 'Macarrão', 'Cerveja"'],
#  ['"Banana', 'Leite', 'Manteiga"'],
#  ['"Manteiga', 'Arroz"'],
#  ['"Macarrão', 'Leite', 'Biscoitos"'],
#  ['"Biscoitos', 'Arroz', 'Macarrão', 'Café', 'Leite', 'Ovos"'],
#  ['"Manteiga', 'Pão', 'Arroz', 'Macarrão"'],
#  ['"Leite', 'Pão', 'Manteiga', 'Feijão', 'Arroz"'],
#  ['"Frango', 'Feijão', 'Ovos', 'Biscoitos', 'Açúcar"'],
#  ['"Macarrão', 'Banana', 'Ovos"'],
#  ['"Banana', 'Leite', 'Queijo', 'Frango', 'Açúcar', 'Manteiga"'],
#  ['"Leite', 'Biscoitos', 'Manteiga"'],
#  ['"Frango', 'Cerveja', 'Banana"'],
#  ['"Arroz', 'Açúcar', 'Pão', 'Biscoitos', 'Manteiga"'],
#  ['"Pão', 'Frango', 'Manteiga', 'Banana"'],
#  ['"Banana', 'Ovos', 'Leite', 'Biscoitos', 'Pão"'],
#  ['"Arroz', 'Banana', 'Açúcar', 'Leite', 'Biscoitos', 'Ovos"'],
#  ['"Café', 'Feijão', 'Frango"'],
#  ['"Banana', 'Arroz"'],
#  ['"Biscoitos', 'Manteiga"'],
#  ['"Café', 'Cerveja"'],
#  ['"Frango', 'Biscoitos', 'Queijo', 'Cerveja', 'Ovos"'],
#  ['"Frango', 'Leite', 'Queijo"'],
#  ['"Leite', 'Biscoitos', 'Ovos', 'Macarrão', 'Feijão"'],
#  ['"Leite', 'Frango', 'Feijão', 'Macarrão', 'Café"'],
#  ['"Café', 'Banana', 'Manteiga', 'Arroz"'],
#  ['"Macarrão', 'Banana', 'Biscoitos', 'Frango', 'Pão"'],
#  ['"Banana', 'Açúcar', 'Frango"'],
#  ['"Manteiga', 'Queijo', 'Cerveja', 'Pão', 'Ovos', 'Açúcar"'],
#  ['"Biscoitos', 'Café', 'Queijo', 'Arroz"'],
#  ['"Manteiga', 'Leite', 'Frango', 'Banana', 'Açúcar"'],
#  ['"Cerveja', 'Queijo', 'Banana"'],
#  ['"Frango', 'Pão', 'Biscoitos', 'Feijão"'],
#  ['"Açúcar', 'Arroz', 'Ovos', 'Pão', 'Queijo', 'Leite"'],
#  ['"Ovos', 'Manteiga', 'Banana"'],
#  ['"Café', 'Macarrão"'],
#  ['"Pão', 'Café"'],
#  ['"Queijo', 'Ovos', 'Biscoitos', 'Banana', 'Cerveja"'],
#  ['"Ovos', 'Açúcar', 'Feijão', 'Biscoitos', 'Queijo', 'Macarrão"'],
#  ['"Banana', 'Macarrão', 'Queijo', 'Ovos', 'Cerveja', 'Açúcar"'],
#  ['"Frango', 'Arroz', 'Açúcar"'],
#  ['"Ovos', 'Leite', 'Café', 'Queijo', 'Macarrão', 'Cerveja"'],
#  ['"Cerveja', 'Banana', 'Açúcar"'],
#  ['"Açúcar', 'Banana', 'Pão', 'Biscoitos"'],
#  ['"Macarrão', 'Frango', 'Manteiga"'],
#  ['"Café', 'Manteiga', 'Macarrão', 'Leite', 'Frango', 'Pão"'],
#  ['"Queijo', 'Banana', 'Leite"'],
#  ['"Feijão', 'Banana', 'Arroz', 'Cerveja', 'Açúcar', 'Ovos"'],
#  ['"Ovos', 'Frango', 'Cerveja', 'Café', 'Açúcar', 'Biscoitos"'],
#  ['"Arroz', 'Cerveja', 'Feijão', 'Pão', 'Açúcar"'],
#  ['"Café', 'Arroz', 'Biscoitos', 'Cerveja', 'Açúcar', 'Leite"'],
#  ['"Frango', 'Queijo', 'Manteiga', 'Cerveja', 'Arroz"'],
#  ['"Arroz', 'Ovos', 'Manteiga"'],
#  ['"Queijo', 'Frango', 'Café"'],
#  ['"Cerveja', 'Macarrão', 'Açúcar', 'Café', 'Leite', 'Feijão"'],
#  ['"Macarrão', 'Açúcar', 'Feijão', 'Pão', 'Manteiga"'],
#  ['"Pão', 'Açúcar"'],
#  ['"Pão', 'Arroz', 'Biscoitos"'],
#  ['"Macarrão', 'Queijo', 'Arroz', 'Leite', 'Biscoitos', 'Cerveja"'],
#  ['"Arroz', 'Queijo', 'Macarrão', 'Banana', 'Feijão"'],
#  ['"Queijo', 'Arroz"'],
#  ['"Queijo', 'Leite', 'Manteiga', 'Macarrão', 'Arroz"'],
#  ['"Banana', 'Ovos', 'Leite"'],
#  ['"Frango', 'Queijo', 'Banana', 'Biscoitos', 'Cerveja', 'Açúcar"'],
#  ['"Feijão', 'Manteiga', 'Cerveja', 'Açúcar"'],
#  ['"Pão', 'Manteiga"'],
#  ['"Banana', 'Leite', 'Frango"'],
#  ['"Macarrão', 'Açúcar', 'Pão', 'Frango', 'Feijão"'],
#  ['"Cerveja', 'Açúcar', 'Arroz', 'Feijão"'],
#  ['"Pão', 'Macarrão', 'Manteiga"'],
#  ['"Feijão', 'Macarrão', 'Frango', 'Leite"'],
#  ['"Biscoitos', 'Frango', 'Feijão', 'Pão', 'Café', 'Manteiga"'],
#  ['"Banana', 'Pão', 'Biscoitos', 'Ovos"'],
#  ['"Ovos', 'Feijão', 'Café', 'Macarrão', 'Pão"'],
#  ['"Queijo', 'Biscoitos"'],
#  ['"Macarrão', 'Açúcar', 'Banana', 'Arroz', 'Biscoitos"'],
#  ['"Cerveja', 'Pão"'],
#  ['"Café', 'Arroz', 'Cerveja', 'Queijo"'],
#  ['"Leite', 'Macarrão', 'Queijo', 'Ovos', 'Biscoitos"'],
#  ['"Frango', 'Cerveja', 'Ovos', 'Açúcar"'],
#  ['"Queijo', 'Leite', 'Banana', 'Arroz', 'Café"'],
#  ['"Manteiga', 'Frango', 'Queijo', 'Açúcar', 'Pão"'],
#  ['"Leite', 'Café', 'Ovos"'],
#  ['"Cerveja', 'Café', 'Feijão', 'Banana', 'Frango"'],
#  ['"Biscoitos', 'Queijo', 'Manteiga', 'Pão', 'Leite"'],
#  ['"Açúcar', 'Pão"'],
#  ['"Açúcar', 'Café"'],
#  ['"Cerveja', 'Pão', 'Café', 'Manteiga', 'Açúcar', 'Arroz"'],
#  ['"Manteiga', 'Café', 'Queijo', 'Cerveja"'],
#  ['"Leite', 'Banana"'],
#  ['"Arroz', 'Leite', 'Frango', 'Cerveja', 'Manteiga', 'Ovos"'],
#  ['"Macarrão', 'Açúcar', 'Arroz', 'Café"'],
#  ['"Frango', 'Cerveja', 'Macarrão', 'Manteiga"'],
#  ['"Pão', 'Arroz"'],
#  ['"Macarrão', 'Queijo', 'Ovos', 'Pão', 'Açúcar', 'Biscoitos"'],
#  ['"Feijão', 'Manteiga', 'Leite', 'Arroz', 'Banana"'],
#  ['"Pão', 'Manteiga"'],
#  ['"Biscoitos', 'Açúcar"'],
#  ['"Banana', 'Queijo', 'Cerveja"'],
#  ['"Arroz', 'Leite', 'Frango', 'Açúcar', 'Café"'],
#  ['"Arroz', 'Queijo', 'Manteiga', 'Banana', 'Café', 'Cerveja"'],
#  ['"Biscoitos', 'Frango', 'Feijão', 'Açúcar"'],
#  ['"Biscoitos', 'Feijão', 'Leite', 'Banana', 'Açúcar', 'Pão"'],
#  ['"Pão', 'Queijo', 'Manteiga', 'Café', 'Feijão"'],
#  ['"Frango', 'Ovos', 'Feijão', 'Café', 'Leite"'],
#  ['"Pão', 'Café', 'Macarrão', 'Leite"'],
#  ['"Manteiga', 'Arroz', 'Biscoitos"'],
#  ['"Biscoitos', 'Frango', 'Arroz', 'Café"'],
#  ['"Pão', 'Manteiga', 'Arroz', 'Macarrão', 'Café"'],
#  ['"Arroz', 'Ovos', 'Leite', 'Macarrão', 'Açúcar', 'Café"'],
#  ['"Frango', 'Leite', 'Açúcar', 'Arroz"'],
#  ['"Açúcar', 'Frango', 'Pão', 'Queijo"'],
#  ['"Frango', 'Ovos', 'Açúcar', 'Café', 'Leite', 'Feijão"'],
#  ['"Queijo', 'Arroz"'],
#  ['"Café', 'Queijo', 'Pão', 'Biscoitos"'],
#  ['"Queijo', 'Pão"'],
#  ['"Macarrão', 'Ovos', 'Pão', 'Manteiga"'],
#  ['"Queijo', 'Feijão', 'Café', 'Macarrão', 'Arroz', 'Manteiga"'],
#  ['"Macarrão', 'Banana', 'Cerveja', 'Café"'],
#  ['"Macarrão', 'Biscoitos"'],
#  ['"Pão', 'Queijo"'],
#  ['"Feijão', 'Açúcar', 'Arroz', 'Queijo', 'Biscoitos"'],
#  ['"Macarrão', 'Frango', 'Biscoitos', 'Queijo', 'Leite', 'Café"'],
#  ['"Açúcar', 'Leite', 'Pão', 'Arroz', 'Macarrão"'],
#  ['"Manteiga', 'Biscoitos"'],
#  ['"Biscoitos', 'Manteiga', 'Pão', 'Frango"'],
#  ['"Leite', 'Arroz', 'Açúcar', 'Banana', 'Queijo"'],
#  ['"Feijão', 'Banana"'],
#  ['"Biscoitos', 'Arroz', 'Açúcar"'],
#  ['"Biscoitos', 'Ovos', 'Café', 'Arroz', 'Manteiga"'],
#  ['"Leite', 'Macarrão"'],
#  ['"Banana', 'Arroz', 'Cerveja', 'Pão', 'Leite', 'Ovos"'],
#  ['"Açúcar', 'Manteiga', 'Pão"'],
#  ['"Frango', 'Queijo', 'Cerveja', 'Leite', 'Macarrão', 'Café"'],
#  ['"Macarrão', 'Leite', 'Arroz', 'Pão', 'Café"'],
#  ['"Frango', 'Leite', 'Arroz"'],
#  ['"Manteiga', 'Arroz', 'Açúcar', 'Café', 'Feijão', 'Macarrão"'],
#  ['"Biscoitos', 'Feijão', 'Café', 'Manteiga', 'Açúcar', 'Frango"'],
#  ['"Pão', 'Cerveja', 'Ovos', 'Feijão', 'Café"'],
#  ['"Biscoitos', 'Frango', 'Manteiga"'],
#  ['"Pão', 'Macarrão', 'Arroz', 'Biscoitos"'],
#  ['"Café', 'Feijão', 'Cerveja', 'Frango', 'Ovos"'],
#  ['"Feijão', 'Café"'],
#  ['"Pão', 'Ovos', 'Frango', 'Leite', 'Biscoitos', 'Macarrão"'],
#  ['"Café', 'Macarrão', 'Cerveja', 'Arroz', 'Frango', 'Pão"'],
#  ['"Açúcar', 'Macarrão"'],
#  ['"Cerveja', 'Café', 'Feijão', 'Açúcar', 'Queijo', 'Manteiga"'],
#  ['"Ovos', 'Cerveja', 'Queijo', 'Açúcar', 'Café"'],
#  ['"Macarrão', 'Leite', 'Ovos"'],
#  ['"Açúcar', 'Frango', 'Feijão', 'Leite', 'Café', 'Queijo"'],
#  ['"Pão', 'Açúcar', 'Leite', 'Arroz', 'Frango"'],
#  ['"Pão', 'Café"'],
#  ['"Pão', 'Açúcar', 'Banana', 'Arroz', 'Macarrão"'],
#  ['"Leite', 'Feijão', 'Banana', 'Ovos', 'Pão"'],
#  ['"Biscoitos', 'Leite', 'Frango"'],
#  ['"Pão', 'Macarrão', 'Frango', 'Açúcar', 'Café', 'Cerveja"'],
#  ['"Biscoitos', 'Banana', 'Frango"'],
#  ['"Leite', 'Cerveja', 'Queijo', 'Macarrão"'],
#  ['"Manteiga', 'Café', 'Frango', 'Macarrão', 'Biscoitos"'],
#  ['"Cerveja', 'Banana', 'Feijão', 'Frango"'],
#  ['"Biscoitos', 'Açúcar', 'Café', 'Banana"'],
#  ['"Café', 'Frango', 'Biscoitos', 'Pão', 'Queijo', 'Banana"'],
#  ['"Café', 'Frango"'],
#  ['"Café', 'Leite"'],
#  ['"Biscoitos', 'Açúcar"'],
#  ['"Queijo', 'Leite', 'Biscoitos', 'Arroz', 'Ovos', 'Cerveja"'],
#  ['"Pão', 'Açúcar"'],
#  ['"Café', 'Frango', 'Banana', 'Macarrão', 'Pão"'],
#  ['"Biscoitos', 'Frango', 'Feijão"'],
#  ['"Ovos', 'Banana', 'Açúcar', 'Biscoitos', 'Pão', 'Feijão"'],
#  ['"Café', 'Arroz', 'Leite', 'Açúcar', 'Frango"'],
#  ['"Arroz', 'Feijão', 'Frango', 'Café"'],
#  ['"Biscoitos', 'Queijo', 'Ovos"'],
#  ['"Frango', 'Feijão', 'Açúcar', 'Manteiga', 'Banana"'],
#  ['"Feijão', 'Frango', 'Banana', 'Cerveja', 'Café"'],
#  ['"Leite', 'Pão', 'Açúcar"'],
#  ['"Frango', 'Macarrão', 'Banana', 'Biscoitos"'],
#  ['"Cerveja', 'Biscoitos"'],
#  ['"Cerveja', 'Biscoitos', 'Café', 'Pão', 'Ovos"'],
#  ['"Açúcar', 'Café', 'Feijão', 'Leite', 'Ovos"'],
#  ['"Ovos', 'Açúcar"'],
#  ['"Biscoitos', 'Banana', 'Feijão', 'Açúcar', 'Cerveja', 'Manteiga"'],
#  ['"Feijão', 'Pão', 'Cerveja', 'Açúcar', 'Queijo"'],
#  ['"Frango', 'Macarrão', 'Ovos', 'Café', 'Cerveja', 'Pão"'],
#  ['"Manteiga', 'Biscoitos', 'Açúcar"'],
#  ['"Feijão', 'Café"'],
#  ['"Ovos', 'Arroz', 'Açúcar', 'Leite"'],
#  ['"Frango', 'Arroz', 'Banana', 'Manteiga"'],
#  ['"Feijão', 'Manteiga', 'Ovos', 'Leite', 'Frango', 'Biscoitos"'],
#  ['"Biscoitos', 'Banana', 'Frango', 'Arroz"'],
#  ['"Banana', 'Leite"'],
#  ['"Biscoitos', 'Ovos"'],
#  ['"Leite', 'Queijo', 'Frango', 'Banana"'],
#  ['"Queijo', 'Feijão"'],
#  ['"Banana', 'Cerveja', 'Leite', 'Frango', 'Pão"'],
#  ['"Banana', 'Leite', 'Biscoitos', 'Feijão', 'Ovos', 'Arroz"'],
#  ['"Ovos', 'Pão', 'Banana"'],
#  ['"Banana', 'Ovos', 'Manteiga', 'Feijão', 'Arroz"'],
#  ['"Macarrão', 'Manteiga"'],
#  ['"Frango', 'Feijão', 'Cerveja', 'Queijo"'],
#  ['"Leite', 'Biscoitos', 'Feijão', 'Pão', 'Manteiga', 'Macarrão"'],
#  ['"Queijo', 'Feijão', 'Biscoitos', 'Arroz', 'Banana"'],
#  ['"Frango', 'Leite', 'Pão', 'Macarrão', 'Queijo"'],
#  ['"Ovos', 'Arroz', 'Banana', 'Biscoitos"'],
#  ['"Frango', 'Macarrão', 'Açúcar', 'Manteiga"'],
#  ['"Leite', 'Açúcar', 'Ovos"'],
#  ['"Macarrão', 'Café"'],
#  ['"Arroz', 'Pão', 'Feijão', 'Açúcar"'],
#  ['"Macarrão', 'Frango', 'Biscoitos', 'Arroz', 'Leite"'],
#  ['"Banana', 'Cerveja"'],
#  ['"Ovos', 'Arroz', 'Café', 'Banana', 'Feijão"'],
#  ['"Frango', 'Café', 'Ovos', 'Arroz', 'Açúcar', 'Macarrão"'],
#  ['"Manteiga', 'Pão', 'Banana', 'Arroz', 'Leite', 'Café"'],
#  ['"Manteiga', 'Cerveja', 'Queijo', 'Ovos', 'Arroz"'],
#  ['"Feijão', 'Frango"'],
#  ['"Manteiga', 'Açúcar', 'Café"'],
#  ['"Queijo', 'Frango"'],
#  ['"Café', 'Banana', 'Açúcar"'],
#  ['"Banana', 'Cerveja', 'Arroz"'],
#  ['"Café', 'Açúcar"'],
#  ['"Manteiga', 'Frango', 'Pão', 'Queijo', 'Açúcar', 'Arroz"'],
#  ['"Arroz', 'Leite', 'Cerveja', 'Açúcar', 'Feijão"'],
#  ['"Leite', 'Ovos', 'Café"'],
#  ['"Queijo', 'Banana', 'Leite"'],
#  ['"Macarrão', 'Frango"'],
#  ['"Feijão', 'Banana', 'Manteiga', 'Biscoitos', 'Café"'],
#  ['"Banana', 'Ovos', 'Macarrão', 'Pão"'],
#  ['"Café', 'Manteiga', 'Ovos"'],
#  ['"Cerveja', 'Pão', 'Ovos', 'Macarrão', 'Açúcar', 'Café"'],
#  ['"Queijo', 'Banana', 'Cerveja"'],
#  ['"Feijão', 'Arroz"'],
#  ['"Feijão', 'Pão', 'Cerveja"'],
#  ['"Leite', 'Banana', 'Ovos', 'Pão"'],
#  ['"Manteiga', 'Café', 'Leite', 'Arroz"'],
#  ['"Arroz', 'Frango', 'Ovos', 'Banana', 'Café', 'Queijo"'],
#  ['"Café', 'Queijo', 'Leite"'],
#  ['"Biscoitos', 'Ovos', 'Café"'],
#  ['"Frango', 'Queijo', 'Biscoitos', 'Cerveja"'],
#  ['"Ovos', 'Frango', 'Manteiga"'],
#  ['"Manteiga', 'Cerveja', 'Ovos', 'Frango', 'Biscoitos"'],
#  ['"Manteiga', 'Feijão"'],
#  ['"Frango', 'Banana"'],
#  ['"Cerveja', 'Biscoitos', 'Ovos', 'Macarrão', 'Queijo"'],
#  ['"Leite', 'Cerveja"'],
#  ['"Café', 'Feijão', 'Banana"'],
#  ['"Manteiga', 'Biscoitos', 'Ovos', 'Açúcar', 'Frango"'],
#  ['"Banana', 'Macarrão', 'Biscoitos"'],
#  ['"Arroz', 'Ovos"'],
#  ['"Manteiga', 'Frango', 'Café"'],
#  ['"Pão', 'Biscoitos', 'Feijão', 'Açúcar"'],
#  ['"Leite', 'Banana', 'Biscoitos', 'Arroz', 'Açúcar', 'Café"'],
#  ['"Queijo', 'Café', 'Macarrão', 'Açúcar', 'Feijão', 'Arroz"'],
#  ['"Leite', 'Arroz', 'Pão', 'Macarrão', 'Feijão', 'Banana"'],
#  ['"Ovos', 'Manteiga', 'Arroz"'],
#  ['"Café', 'Manteiga', 'Arroz', 'Cerveja"'],
#  ['"Pão', 'Queijo', 'Biscoitos', 'Feijão', 'Cerveja', 'Ovos"'],
#  ['"Banana', 'Arroz', 'Feijão"'],
#  ['"Manteiga', 'Biscoitos', 'Frango', 'Cerveja"'],
#  ['"Frango', 'Leite', 'Café"'],
#  ['"Feijão', 'Manteiga"'],
#  ['"Ovos', 'Açúcar', 'Leite"'],
#  ['"Banana', 'Biscoitos', 'Queijo', 'Arroz"'],
#  ['"Queijo', 'Biscoitos"'],
#  ['"Café', 'Cerveja', 'Arroz', 'Frango', 'Biscoitos"'],
#  ['"Queijo', 'Banana', 'Leite', 'Feijão', 'Frango"'],
#  ['"Pão', 'Açúcar"'],
#  ['"Pão', 'Leite', 'Biscoitos', 'Açúcar"'],
#  ['"Arroz', 'Café', 'Queijo', 'Macarrão', 'Leite"'],
#  ['"Café', 'Açúcar', 'Pão', 'Feijão', 'Queijo', 'Biscoitos"'],
#  ['"Açúcar', 'Manteiga', 'Ovos', 'Banana', 'Biscoitos', 'Feijão"'],
#  ['"Arroz', 'Macarrão', 'Pão"'],
#  ['"Macarrão', 'Feijão', 'Leite"'],
#  ['"Frango', 'Biscoitos', 'Queijo', 'Macarrão', 'Arroz"'],
#  ['"Frango', 'Biscoitos"'],
#  ['"Açúcar', 'Feijão', 'Frango', 'Ovos"'],
#  ['"Cerveja', 'Feijão', 'Queijo"'],
#  ['"Feijão', 'Leite', 'Queijo', 'Pão', 'Biscoitos"'],
#  ['"Queijo', 'Cerveja', 'Banana', 'Manteiga', 'Pão', 'Biscoitos"'],
#  ['"Ovos', 'Açúcar', 'Banana', 'Leite"'],
#  ['"Açúcar', 'Ovos', 'Biscoitos', 'Macarrão', 'Manteiga', 'Café"'],
#  ['"Feijão', 'Manteiga"'],
#  ['"Biscoitos', 'Feijão"'],
#  ['"Biscoitos', 'Açúcar', 'Banana', 'Pão', 'Manteiga', 'Leite"'],
#  ['"Frango', 'Pão', 'Café', 'Queijo"'],
#  ['"Feijão', 'Queijo', 'Banana', 'Biscoitos', 'Café"'],
#  ['"Feijão', 'Cerveja', 'Biscoitos"'],
#  ['"Banana', 'Pão', 'Ovos"'],
#  ['"Queijo', 'Biscoitos"'],
#  ['"Cerveja', 'Macarrão"'],
#  ['"Cerveja', 'Pão', 'Arroz"'],
#  ['"Frango', 'Manteiga', 'Ovos"'],
#  ['"Açúcar', 'Biscoitos', 'Pão', 'Cerveja"'],
#  ['"Café', 'Macarrão', 'Arroz', 'Açúcar', 'Frango"'],
#  ['"Macarrão', 'Cerveja', 'Pão"'],
#  ['"Banana', 'Café', 'Frango', 'Pão', 'Queijo', 'Biscoitos"'],
#  ['"Banana', 'Açúcar', 'Feijão', 'Arroz"'],
#  ['"Cerveja', 'Frango', 'Feijão', 'Manteiga"'],
#  ['"Leite', 'Cerveja', 'Manteiga', 'Pão', 'Queijo"'],
#  ['"Café', 'Frango', 'Feijão', 'Pão', 'Ovos', 'Macarrão"'],
#  ['"Açúcar', 'Cerveja', 'Café', 'Leite', 'Ovos', 'Banana"'],
#  ['"Feijão', 'Manteiga', 'Macarrão"'],
#  ['"Leite', 'Café"'],
#  ['"Arroz', 'Banana', 'Queijo', 'Açúcar', 'Feijão', 'Cerveja"'],
#  ['"Açúcar', 'Arroz', 'Macarrão', 'Ovos', 'Pão', 'Queijo"'],
#  ['"Manteiga', 'Frango"'],
#  ['"Manteiga', 'Biscoitos', 'Queijo', 'Frango"'],
#  ['"Açúcar', 'Ovos"'],
#  ['"Leite', 'Ovos', 'Queijo', 'Banana', 'Macarrão"'],
#  ['"Queijo', 'Banana', 'Manteiga', 'Ovos', 'Macarrão"'],
#  ['"Café', 'Banana', 'Queijo', 'Macarrão', 'Manteiga', 'Feijão"'],
#  ['"Arroz', 'Leite', 'Manteiga', 'Ovos"'],
#  ['"Manteiga', 'Pão', 'Biscoitos', 'Banana"'],
#  ['"Frango', 'Açúcar"'],
#  ['"Feijão', 'Café', 'Leite', 'Manteiga"'],
#  ['"Queijo', 'Frango', 'Leite', 'Café', 'Arroz"'],
#  ['"Café', 'Queijo', 'Açúcar', 'Manteiga', 'Macarrão', 'Biscoitos"'],
#  ['"Banana', 'Queijo', 'Arroz"'],
#  ['"Açúcar', 'Café', 'Pão', 'Biscoitos', 'Leite"'],
#  ['"Arroz', 'Açúcar', 'Banana', 'Café', 'Frango"'],
#  ['"Macarrão', 'Leite', 'Pão"'],
#  ['"Leite', 'Arroz', 'Ovos', 'Feijão', 'Queijo"'],
#  ['"Leite', 'Cerveja', 'Frango"'],
#  ['"Açúcar', 'Leite', 'Biscoitos', 'Arroz', 'Macarrão', 'Cerveja"'],
#  ['"Pão', 'Ovos"'],
#  ['"Macarrão', 'Açúcar', 'Banana', 'Pão"'],
#  ['"Pão', 'Macarrão', 'Feijão', 'Manteiga', 'Ovos', 'Biscoitos"'],
#  ['"Pão', 'Frango"'],
#  ['"Feijão', 'Leite', 'Cerveja', 'Açúcar"'],
#  ['"Cerveja', 'Arroz', 'Feijão"'],
#  ['"Manteiga', 'Queijo"'],
#  ['"Pão', 'Banana', 'Biscoitos', 'Manteiga', 'Leite', 'Açúcar"'],
#  ['"Açúcar', 'Macarrão"'],
#  ['"Biscoitos', 'Pão"'],
#  ['"Açúcar', 'Feijão', 'Macarrão', 'Banana', 'Ovos"'],
#  ['"Biscoitos', 'Banana', 'Manteiga"'],
#  ['"Feijão', 'Ovos', 'Queijo', 'Pão', 'Arroz"'],
#  ['"Arroz', 'Queijo', 'Café', 'Pão', 'Banana', 'Açúcar"'],
#  ['"Cerveja', 'Frango', 'Macarrão', 'Queijo', 'Pão"'],
#  ['"Cerveja', 'Açúcar', 'Frango', 'Macarrão', 'Banana', 'Leite"'],
#  ['"Manteiga', 'Ovos', 'Café', 'Leite"'],
#  ['"Açúcar', 'Feijão', 'Café', 'Frango"'],
#  ['"Manteiga', 'Leite', 'Ovos', 'Cerveja"'],
#  ['"Ovos', 'Macarrão"'],
#  ['"Queijo', 'Leite', 'Pão', 'Manteiga"'],
#  ['"Arroz', 'Leite', 'Pão', 'Cerveja', 'Manteiga"'],
#  ['"Macarrão', 'Pão', 'Leite', 'Banana', 'Cerveja"'],
#  ['"Cerveja', 'Arroz', 'Feijão"'],
#  ['"Banana', 'Feijão', 'Manteiga', 'Leite', 'Ovos"'],
#  ['"Leite', 'Biscoitos', 'Cerveja', 'Queijo"'],
#  ['"Biscoitos', 'Feijão', 'Café', 'Açúcar', 'Leite', 'Banana"'],
#  ['"Leite', 'Macarrão', 'Açúcar', 'Queijo', 'Frango"'],
#  ['"Açúcar', 'Feijão', 'Queijo"'],
#  ['"Queijo', 'Feijão', 'Frango', 'Pão"'],
#  ['"Queijo', 'Banana"'],
#  ['"Macarrão', 'Biscoitos"'],
#  ['"Cerveja', 'Macarrão', 'Frango', 'Café', 'Feijão"'],
#  ['"Pão', 'Frango', 'Macarrão"'],
#  ['"Café', 'Açúcar', 'Biscoitos', 'Ovos"'],
#  ['"Banana', 'Feijão', 'Pão"'],
#  ['"Frango', 'Leite', 'Pão"'],
#  ['"Pão', 'Frango"'],
#  ['"Arroz', 'Manteiga', 'Feijão', 'Queijo', 'Banana', 'Pão"'],
#  ['"Ovos', 'Banana', 'Macarrão', 'Pão', 'Açúcar', 'Arroz"'],
#  ['"Açúcar', 'Ovos', 'Leite', 'Frango"'],
#  ['"Leite', 'Café', 'Macarrão', 'Biscoitos"'],
#  ['"Biscoitos', 'Café', 'Açúcar', 'Frango"'],
#  ['"Ovos', 'Feijão', 'Pão', 'Cerveja"'],
#  ['"Cerveja', 'Manteiga', 'Arroz"'],
#  ['"Biscoitos', 'Café', 'Queijo', 'Pão"'],
#  ['"Ovos', 'Feijão', 'Pão', 'Manteiga"'],
#  ['"Frango', 'Cerveja"'],
#  ['"Banana', 'Feijão', 'Leite"'],
#  ['"Leite', 'Feijão"'],
#  ['"Ovos', 'Biscoitos', 'Café', 'Manteiga"'],
#  ['"Cerveja', 'Café', 'Açúcar', 'Arroz"'],
#  ['"Açúcar', 'Arroz"'],
#  ['"Cerveja', 'Ovos"'],
#  ['"Manteiga', 'Macarrão"'],
#  ['"Leite', 'Feijão', 'Arroz', 'Cerveja', 'Queijo', 'Manteiga"'],
#  ['"Açúcar', 'Café"'],
#  ['"Queijo', 'Manteiga"'],
#  ['"Café', 'Manteiga', 'Pão', 'Cerveja', 'Ovos"'],
#  ['"Leite', 'Macarrão', 'Cerveja', 'Feijão', 'Café"'],
#  ['"Café', 'Macarrão"'],
#  ['"Frango', 'Macarrão', 'Leite"'],
#  ['"Biscoitos', 'Banana"'],
#  ['"Feijão', 'Arroz', 'Banana', 'Frango', 'Cerveja"'],
#  ['"Pão', 'Açúcar', 'Cerveja', 'Manteiga', 'Ovos"'],
#  ['"Cerveja', 'Ovos', 'Biscoitos"'],
#  ['"Ovos', 'Macarrão', 'Cerveja', 'Banana', 'Café', 'Manteiga"'],
#  ['"Pão', 'Arroz', 'Açúcar', 'Macarrão', 'Cerveja', 'Biscoitos"'],
#  ['"Cerveja', 'Queijo', 'Café', 'Manteiga', 'Feijão"'],
#  ['"Pão', 'Queijo', 'Cerveja', 'Açúcar"'],
#  ['"Ovos', 'Feijão', 'Queijo', 'Frango', 'Macarrão', 'Manteiga"'],
#  ['"Cerveja', 'Ovos', 'Frango"'],
#  ['"Feijão', 'Queijo', 'Arroz', 'Leite"'],
#  ['"Banana', 'Pão', 'Queijo"'],
#  ['"Manteiga', 'Arroz', 'Macarrão', 'Café', 'Ovos', 'Feijão"'],
#  ['"Café', 'Manteiga"'],
#  ['"Banana', 'Macarrão', 'Feijão', 'Frango"'],
#  ['"Frango', 'Cerveja', 'Café', 'Banana', 'Açúcar', 'Queijo"'],
#  ['"Leite', 'Frango', 'Cerveja', 'Pão', 'Queijo', 'Ovos"'],
#  ['"Macarrão', 'Café', 'Açúcar', 'Arroz', 'Manteiga"'],
#  ['"Biscoitos', 'Frango"'],
#  ['"Manteiga', 'Ovos"'],
#  ['"Café', 'Feijão', 'Macarrão', 'Leite', 'Banana', 'Manteiga"'],
#  ['"Cerveja', 'Feijão"'],
#  ['"Cerveja', 'Manteiga', 'Ovos', 'Arroz"'],
#  ['"Queijo', 'Macarrão', 'Pão"'],
#  ['"Café', 'Macarrão', 'Leite', 'Açúcar"'],
#  ['"Biscoitos', 'Manteiga', 'Banana', 'Pão"'],
#  ['"Queijo', 'Frango', 'Café', 'Leite', 'Feijão"'],
#  ['"Macarrão', 'Cerveja', 'Queijo', 'Café', 'Pão', 'Biscoitos"'],
#  ['"Café', 'Cerveja', 'Manteiga', 'Frango', 'Biscoitos"'],
#  ['"Pão', 'Leite', 'Manteiga', 'Arroz', 'Macarrão', 'Banana"'],
#  ['"Frango', 'Arroz"'],
#  ['"Pão', 'Feijão', 'Macarrão', 'Banana', 'Manteiga', 'Frango"'],
#  ['"Ovos', 'Banana"'],
#  ['"Banana', 'Açúcar', 'Ovos', 'Frango"'],
#  ['"Ovos', 'Pão"'],
#  ['"Queijo', 'Ovos', 'Leite"'],
#  ['"Cerveja', 'Feijão', 'Queijo', 'Frango"'],
#  ['"Banana', 'Cerveja', 'Feijão', 'Arroz"'],
#  ['"Biscoitos', 'Ovos', 'Manteiga', 'Queijo"'],
#  ['"Arroz', 'Ovos"'],
#  ['"Leite', 'Macarrão', 'Manteiga', 'Ovos', 'Pão"'],
#  ['"Arroz', 'Cerveja', 'Café', 'Feijão', 'Banana"'],
#  ['"Arroz', 'Manteiga', 'Açúcar"'],
#  ['"Açúcar', 'Arroz', 'Manteiga', 'Pão', 'Macarrão', 'Frango"'],
#  ['"Feijão', 'Cerveja', 'Queijo"'],
#  ['"Feijão', 'Banana', 'Macarrão', 'Manteiga"'],
#  ['"Macarrão', 'Frango', 'Ovos', 'Feijão', 'Manteiga"'],
#  ['"Biscoitos', 'Banana', 'Feijão', 'Queijo', 'Ovos', 'Açúcar"'],
#  ['"Biscoitos', 'Açúcar', 'Cerveja', 'Queijo', 'Macarrão', 'Manteiga"'],
#  ['"Açúcar', 'Arroz', 'Queijo', 'Banana', 'Pão', 'Manteiga"'],
#  ['"Macarrão', 'Feijão', 'Açúcar', 'Pão', 'Frango', 'Leite"'],
#  ['"Pão', 'Ovos', 'Cerveja"'],
#  ['"Cerveja', 'Ovos"'],
#  ['"Leite', 'Banana"'],
#  ['"Feijão', 'Queijo', 'Ovos"'],
#  ['"Queijo', 'Frango', 'Pão', 'Feijão"'],
#  ['"Queijo', 'Arroz', 'Cerveja', 'Café', 'Açúcar"'],
#  ['"Açúcar', 'Cerveja"'],
#  ['"Macarrão', 'Café', 'Arroz', 'Açúcar', 'Biscoitos"'],
#  ['"Arroz', 'Café"'],
#  ['"Arroz', 'Feijão', 'Macarrão', 'Frango', 'Cerveja"'],
#  ['"Macarrão', 'Açúcar', 'Feijão', 'Arroz', 'Banana', 'Café"'],
#  ['"Cerveja', 'Queijo', 'Café', 'Manteiga', 'Açúcar"']]

# %%
# Remove espaços e aspas dos itens
transactions = [[item.strip().replace('"', '') for item in trans] for trans in transactions]

# %% [markdown]
# ### Transforma em formato apropriado de transações

# %%
# produtos em colunas
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head()
# Out:
#    Arroz  Açúcar  Banana  Biscoitos   Café  Cerveja  Feijão  Frango  Leite  \
# 0  False   False   False       True  False    False   False   False   True
# 1   True   False    True       True   True    False   False    True  False
# 2  False    True   False      False  False    False   False    True   True
# 3  False   False   False      False  False     True   False   False  False
# 4  False    True    True      False  False    False   False   False  False
#
#    Macarrão  Manteiga   Ovos    Pão  Queijo
# 0      True      True   True  False    True
# 1     False     False  False   True   False
# 2     False      True   True   True   False
# 3      True     False  False   True   False
# 4     False     False  False  False   False

# %% [markdown]
# ### Minera Itens Frequêntes

# %%
frequent_itemsets = apriori(df, min_support=suporte_minimo, use_colnames=True)
frequent_itemsets
# Out:
#      support                            itemsets
# 0      0.278                             (Arroz)
# 1      0.298                            (Açúcar)
# 2      0.290                            (Banana)
# 3      0.282                         (Biscoitos)
# 4      0.290                              (Café)
# ..       ...                                 ...
# 503    0.010     (Queijo, Leite, Café, Macarrão)
# 504    0.010  (Queijo, Leite, Cerveja, Macarrão)
# 505    0.010   (Feijão, Manteiga, Macarrão, Pão)
# 506    0.010      (Frango, Leite, Pão, Macarrão)
# 507    0.012   (Frango, Queijo, Leite, Macarrão)
#
# [508 rows x 2 columns]

# %% [markdown]
# ### Minera Regras

# %%
regras = association_rules(frequent_itemsets, metric='confidence', min_threshold=confianca_minima)
regras
# Out:
#                      antecedents  consequents  antecedent support  \
# 0                        (Arroz)     (Açúcar)               0.278
# 1                       (Açúcar)      (Arroz)               0.298
# 2                        (Arroz)     (Banana)               0.278
# 3                       (Banana)      (Arroz)               0.290
# 4                        (Arroz)  (Biscoitos)               0.278
# ...                          ...          ...                 ...
# 1213      (Leite, Pão, Macarrão)     (Frango)               0.028
# 1214     (Frango, Queijo, Leite)   (Macarrão)               0.028
# 1215  (Frango, Queijo, Macarrão)      (Leite)               0.018
# 1216   (Frango, Leite, Macarrão)     (Queijo)               0.030
# 1217   (Queijo, Leite, Macarrão)     (Frango)               0.028
#
#       consequent support  support  confidence      lift  representativity  \
# 0                  0.298    0.100    0.359712  1.207088               1.0
# 1                  0.278    0.100    0.335570  1.207088               1.0
# 2                  0.290    0.088    0.316547  1.091541               1.0
# 3                  0.278    0.088    0.303448  1.091541               1.0
# 4                  0.282    0.066    0.237410  0.841880               1.0
# ...                  ...      ...         ...       ...               ...
# 1213               0.296    0.010    0.357143  1.206564               1.0
# 1214               0.278    0.012    0.428571  1.541624               1.0
# 1215               0.290    0.012    0.666667  2.298851               1.0
# 1216               0.266    0.012    0.400000  1.503759               1.0
# 1217               0.296    0.012    0.428571  1.447876               1.0
#
#       leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0     0.017156    1.096382       0.237618  0.210084   0.087909    0.347641
# 1     0.017156    1.086646       0.244387  0.210084   0.079737    0.347641
# 2     0.007380    1.038842       0.116155  0.183333   0.037390    0.309998
# 3     0.007380    1.036535       0.118118  0.183333   0.035247    0.309998
# 4    -0.012396    0.941528      -0.206435  0.133603  -0.062103    0.235726
# ...        ...         ...            ...       ...        ...         ...
# 1213  0.001712    1.095111       0.176132  0.031847   0.086851    0.195463
# 1214  0.004216    1.263500       0.361454  0.040816   0.208548    0.235868
# 1215  0.006780    2.130000       0.575356  0.040541   0.530516    0.354023
# 1216  0.004020    1.223333       0.345361  0.042254   0.182561    0.222556
# 1217  0.003712    1.232000       0.318244  0.038462   0.188312    0.234556
#
# [1218 rows x 14 columns]

# %% [markdown]
# ### Filtra Regras

# %%
regras_filtradas = regras[(regras['lift'] >= lift_minimo) &
                          (regras['antecedents'].apply(lambda x: len(x) >= tamanho_minimo))]
regras_filtradas[['antecedents','consequents','support', 'confidence', 'lift']]
# Out:
#                      antecedents consequents  support  confidence      lift
# 201            (Arroz, Macarrão)    (Açúcar)    0.034    0.472222  1.584638
# 202           (Açúcar, Macarrão)     (Arroz)    0.034    0.425000  1.528777
# 222              (Arroz, Feijão)    (Banana)    0.036    0.461538  1.591512
# 267            (Arroz, Macarrão)      (Café)    0.032    0.444444  1.532567
# 854             (Leite, Cerveja)  (Macarrão)    0.026    0.419355  1.508471
# ...                          ...         ...      ...         ...       ...
# 1208     (Feijão, Pão, Macarrão)  (Manteiga)    0.010    0.500000  1.724138
# 1210        (Frango, Leite, Pão)  (Macarrão)    0.010    0.500000  1.798561
# 1214     (Frango, Queijo, Leite)  (Macarrão)    0.012    0.428571  1.541624
# 1215  (Frango, Queijo, Macarrão)     (Leite)    0.012    0.666667  2.298851
# 1216   (Frango, Leite, Macarrão)    (Queijo)    0.012    0.400000  1.503759
#
# [110 rows x 5 columns]

# %% [markdown]
# ### Estatísticas

# %%
print(f"Total de Regras Geradas: {len(regras)}")
print(f"Total de Regras Filtradas: {len(regras_filtradas)}")
print(f"Suporte Médio: {regras_filtradas['support'].mean():.4f}")
print(f"Confiança Média: {regras_filtradas['confidence'].mean():.4f}")
print(f"Lift Médio: {regras_filtradas['lift'].mean():.4f}")
# Out:
# Total de Regras Geradas: 1218
# Total de Regras Filtradas: 110
# Suporte Médio: 0.0126
# Confiança Média: 0.4980
# Lift Médio: 1.8125
